# %%
import matplotlib.pyplot as plt
from ito_diffusions import *
plt.style.use('dark_background')

# %%
params = {
    'font.size': 14,
    'figure.figsize': (11,14),
    'axes.labelsize': 12,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
}
plt.rcParams.update(params)

# %%
T = 1.0
SCHEME_STEPS = int(1e3)
N_PATHS = 10

# %% [markdown]
# ## Brownian motion sheaf

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)

mixings = [0.0, 0.9, 0.99]

X = BM_sheaf(x0=0, T=T, scheme_steps=SCHEME_STEPS, drift=0, vol=1, n_paths=N_PATHS)

for i, ax in enumerate(axes):
    path_mixing = mixings[i]
    X.path_mixing = path_mixing
    df = X.simulate()
    df.plot(kind='line', ax=ax)
    ax.get_legend().remove()
    ax.set_xlabel('time\n' + r'mixing coefficient $\alpha = ${:.0%}'.format(path_mixing))
    ax.set_ylabel('spot')

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Brownian motion sheaf, with absorption at zero

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)

mixings = [0.0, 0.9, 0.99]

X = BM_sheaf(x0=1, T=T, scheme_steps=SCHEME_STEPS, drift=-1, vol=1, n_paths=N_PATHS,
             barrier=0, barrier_condition='absorb')

for i, ax in enumerate(axes):
    path_mixing = mixings[i]
    X.path_mixing = path_mixing
    df = X.simulate()
    df.plot(kind='line', ax=ax)
    ax.get_legend().remove()
    ax.set_xlabel('time\n' + r'mixing coefficient $\alpha = ${:.0%}'.format(path_mixing))
    ax.set_ylabel('spot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Geometric Brownian motion sheaf

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)

mixings = [0.0, 0.9, 0.99]

X = GBM_sheaf(x0=1, T=T, scheme_steps=SCHEME_STEPS, drift=0, vol=1, n_paths=N_PATHS)
    
for i, ax in enumerate(axes):
    path_mixing = mixings[i]
    X.path_mixing = path_mixing
    df = X.simulate()
    df.plot(kind='line', ax=ax)
    ax.get_legend().remove()
    ax.set_xlabel('time\n' + r'mixing coefficient $\alpha = ${:.0%}'.format(path_mixing))
    ax.set_ylabel('spot')

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Brownian bridge sheaf

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)

alpha = 1
mixings = [0.0, 0.9, 0.99]

X = Alpha_pinned_BM_sheaf(x0=0, T=T, scheme_steps=SCHEME_STEPS, alpha=alpha, vol=1,\
                              pin=-1, n_paths=N_PATHS)
for i, ax in enumerate(axes):
    path_mixing = mixings[i]
    X.path_mixing = path_mixing
    df = X.simulate()
    df.plot(kind='line', ax=ax)
    ax.get_legend().remove()
    ax.set_xlabel('time\n' + r'mixing coefficient $\alpha = ${:.0%}'.format(path_mixing))
    ax.set_ylabel('spot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Vasicek sheaf

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)

alpha = 1
mixings = [0.0, 0.9, 0.99]

X = Vasicek_sheaf(x0=0, T=10, scheme_steps=SCHEME_STEPS, vol=1, long_term=0, mean_reversion=1,\
                n_paths=N_PATHS)

for i, ax in enumerate(axes):
    path_mixing = mixings[i]
    X.path_mixing = path_mixing
    df = X.simulate()
    df.plot(kind='line', ax=ax)
    ax.get_legend().remove()
    ax.set_xlabel('time\n' + r'mixing coefficient $\alpha = ${:.0%}'.format(path_mixing))
    ax.set_ylabel('spot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## CIR sheaf

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)

alpha = 1
mixings = [0.0, 0.9, 0.99]

X = CIR_sheaf(x0=1, T=10, scheme_steps=SCHEME_STEPS, vol=1, long_term=1, mean_reversion=1,\
                n_paths=N_PATHS, barrier=0, barrier_condition='absorb')

for i, ax in enumerate(axes):
    path_mixing = mixings[i]
    X.path_mixing = path_mixing
    df = X.simulate()
    df.plot(kind='line', ax=ax)
    ax.get_legend().remove()
    ax.set_xlabel('time\n' + r'mixing coefficient $\alpha = ${:.0%}'.format(path_mixing))
    ax.set_ylabel('spot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pseudo Geometric Brownian motion

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)

alpha = 1
mixings = [0.0, 0.9, 0.99]

X = pseudo_GBM_sheaf(x0=100, T=10, scheme_steps=SCHEME_STEPS,\
                         drift=0.5, vol=1,\
                         n_paths=N_PATHS)

for i, ax in enumerate(axes):
    path_mixing = mixings[i]
    X.path_mixing = path_mixing
    df = X.simulate()
    df.plot(kind='line', ax=ax)
    ax.get_legend().remove()
    ax.set_xlabel('time\n' + r'mixing coefficient $\alpha = ${:.0%}'.format(path_mixing))
    ax.set_ylabel('spot')

plt.tight_layout()
plt.show()
