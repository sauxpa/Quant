# %%
import pandas as pd
import numpy as np
from datetime import datetime

from numpy import random as rd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from lasso import *

import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
plt.style.use('dark_background')

# %%
params = {
    'font.size': 14,
    'axes.labelsize': 12,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'figure.figsize': (11,7),
}
plt.rcParams.update(params)

# %%
n_epochs = int(1e4)
learning_rate = 0.005

# %% [markdown]
# ## Fetch UST yield data

# %%
START_DATE = datetime(2017,1,18)
END_DATE = datetime(2019,1,14)
xl = pd.ExcelFile('yc_ust.xls')
df = pd.read_excel(xl, index_col='Date')
df = df[df.index>=START_DATE]
df = df[df.index<=END_DATE]
rets = ((df-df.shift(1))/df.shift(1)).iloc[1:]
m, n = rets.shape

# %%
# individual returns
data_raw = np.array(rets)
# returns of a equiweighhted portfolio
target_raw = np.array(rets).sum(axis=1).reshape(-1, 1) / n 

# use two scalers, one for data one for target
# to retain the possibility of scaling back to the original data
scaler_data = StandardScaler()
scaler_target = StandardScaler()
data = scaler_data.fit_transform(data_raw)
target = scaler_target.fit_transform(target_raw)

# %%
fig, ax = plt.subplots(figsize=(21,14), nrows=1, ncols=1)

df.plot(kind='line', ax=ax)
ax.legend(loc='lower left')

# %%
rets.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col1 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col2 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col3 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col13 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col14 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col15 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col16 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col17 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col18 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col19 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col20 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col21 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col22 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col23 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col24 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col25 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col26 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col27 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col28 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row0_col29 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col0 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col2 {
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col3 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col4 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col5 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col6 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col7 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col8 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col9 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col10 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col11 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col12 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col13 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col14 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col15 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col16 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col17 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col18 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col19 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col20 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col21 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col22 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col23 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col24 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col25 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col26 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col27 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col28 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_799f0882_bb9c_11e9_ae7e_b9225aaf35e6row1_col29 {
#             background-color:  #

# %% [markdown]
# ## Train wrapper

# %%
def train(data, 
          target,
          data_raw,
          target_raw,
          l1_strength=0.0, 
          active_features_threshold=0.01,
         ):
    model = Lasso()
    model.X = data
    model.y = target
    model.n_epochs = n_epochs
    model.verbose = False
    model.l1_strength = l1_strength
    model.optim_params = {
        'optimizer_name': 'adam',
        'learning_rate': learning_rate,
    }
    model.active_features_threshold = active_features_threshold
    
    # Train
    model.fit()
    
    # Rescale and compute the sparse regression line
    scaler_target = StandardScaler()
    scaler_target.fit(target_raw)
    y_fit = scaler_target.inverse_transform(np.matmul(data, model.theta_filtered))
        
    # Visualize the replication portfolio weights
    model.bar_plot()
    
    # only plot some tenor
    idx = [1, 2, 5, 10, 30]
    
    # scatter regression
    fig, axes = plt.subplots(figsize=(11,14), nrows=len(idx), ncols=1)
    for i, ax in enumerate(axes):
        ax.scatter(data_raw[:, idx[i]-1], target_raw[:], marker='.', color='w', label='portfolio')
        ax.plot(data_raw[:, idx[i]-1], y_fit, '.r', alpha=0.7, label='replication')
        ax.set_xlabel('{}y yield returns'.format(idx[i]))
        ax.set_ylabel('Portfolio yield returns')
        ax.legend(loc='lower left')
        ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: '{:.2%}'.format(x)))
        ax.yaxis.set_major_formatter(FuncFormatter(lambda x, _: '{:.2%}'.format(x)))

    plt.tight_layout()
    plt.show()
    
    print('L2 tracking error: {:.2f}'.format(np.linalg.norm(y_fit-target_raw.flatten())))
    
    return model

# %% [markdown]
# ## Weak regularization

# %%
model = train(data, 
              target, 
              data_raw,
              target_raw,
              l1_strength=0.5, 
              active_features_threshold=0.01)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
# L2 tracking error: 0.08

# %% [markdown]
# ## Strong regularization

# %%
model = train(data, 
              target, 
              data_raw,
              target_raw,
              l1_strength=1.4, 
              active_features_threshold=0.01)
# Out:
# L2 tracking error: 0.20

# %% [markdown]
# ## Lasso path and number of active features

# %%
path, active_features_path, grid = model.lasso_path(n_l1_strength=20,
                                                    l1_min=0.01,
                                                    l1_max=1.5,
                                                    plot_path=True,
                                                    plot_active_features_path=True,
                                                   )
