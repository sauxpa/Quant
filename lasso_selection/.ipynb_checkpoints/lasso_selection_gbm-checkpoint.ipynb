# %%
import pandas as pd
import numpy as np

from numpy import random as rd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from ito_diffusions import *
from lasso import *
from synthetic_asset_gen import Return_Normal_Gen
from corr_matrix import random_corr_matrix_from_factors

plt.style.use('dark_background')

# %%
params = {
    'font.size': 14,
    'axes.labelsize': 12,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'figure.figsize': (11,7),
}
plt.rcParams.update(params)

# %%
n_steps = 300
n = 100
T = 1
n_epochs = int(5e3)
learning_rate = 0.01

# Number of correlation factors,
# the lower this number, the sparser the replication can be. 
# Indeed, this means the market is driven by a few factors and all
# observable assets are just combinations of these factors.
n_factors = 20

ONE_PCT = 1e-2
# number of business days in a year (for scaling)
DAYS_IN_YEAR = 252

# %% [markdown]
# # Generate artificial prices and returns paths

# %%
def generate_data(corr_matrix=None,
                  vol=None,
                  drift=None,
                  n_steps=n_steps,
                 ):
    """Generate synthetic price series from Brownian sampling.
    """
    gen = Return_Normal_Gen(corr_matrix=corr_matrix,
                            vol=vol,
                            drift=drift,
                            n_steps=n_steps,
                           )
    # returns
    rets = gen.gen_rets()
    
    # individual returns
    data_raw = np.array(rets)
    # returns of a equiweighhted portfolio
    target_raw = np.array(rets).sum(axis=1).reshape(-1, 1) / n 

    scaler_data = StandardScaler()
    scaler_target = StandardScaler()
    data = scaler_data.fit_transform(data_raw)
    target = scaler_target.fit_transform(target_raw)    
    
    gen.plot()
    
    return data, target, data_raw, target_raw

# %% [markdown]
# ## Train wrapper

# %%
def train(data, 
          target,
          data_raw,
          target_raw,
          l1_strength=0.0, 
          active_features_threshold=0.01,
         ):
    model = Lasso()
    model.X = data
    model.y = target
    model.n_epochs = n_epochs
    model.verbose = False
    model.l1_strength = l1_strength
    model.optim_params = {
        'optimizer_name': 'adam',
        'learning_rate': learning_rate,
    }
    model.active_features_threshold = active_features_threshold
    
    # Train
    model.fit()
    
    # Visualize the replication portfolio weights
    model.bar_plot()
    
    # Rescale and compute the sparse regression line    
    scaler_target = StandardScaler()
    scaler_target.fit(target_raw)
    y_fit = scaler_target.inverse_transform(np.matmul(data, model.theta_filtered))
    print('L2 tracking error: {:.2f}'.format(np.linalg.norm(y_fit-target_raw.flatten())))

    return model

# %% [markdown]
# ## Generate artificial asset price paths

# %%
corr_matrix = random_corr_matrix_from_factors(n=n, n_factors=n_factors, eps=0.0)

vol_lo = 20*ONE_PCT/np.sqrt(DAYS_IN_YEAR)
vol_hi = 60*ONE_PCT/np.sqrt(DAYS_IN_YEAR)

drift_lo = -10*ONE_PCT/DAYS_IN_YEAR
drift_hi = 10*ONE_PCT/DAYS_IN_YEAR

vol = rd.uniform(vol_lo, vol_hi, n)
drift = rd.normal(drift_lo, drift_hi, n)
data, target, data_raw, target_raw = generate_data(corr_matrix, vol, drift)

# %%
pd.DataFrame(corr_matrix).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col1 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col2 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col3 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col4 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col5 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col7 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col8 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col9 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col10 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col11 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col12 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col13 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col14 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col15 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col16 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col17 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col18 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col19 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col20 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col21 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col22 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col23 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col24 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col25 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col26 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col27 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col28 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col29 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col30 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col31 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col32 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col33 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col34 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col35 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col36 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col37 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col38 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col39 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col40 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col41 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col42 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col43 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col44 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col45 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col46 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col47 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col48 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col49 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col50 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col51 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col52 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col53 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col54 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col55 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col56 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col57 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col58 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_6f08ee7e_c7d6_11e9_a6c2_7502622b5db9row0_col59 {
#             background

# %% [markdown]
# ### Weak regularization

# %%
model = train(data,
              target, 
              data_raw, 
              target_raw, 
              l1_strength=0.01,
              active_features_threshold=0.1
             )
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
# L2 tracking error: 0.02

# %% [markdown]
# ### Strong regularization
#
# Sparser, larger tracking error

# %%
model = train(data,
              target, 
              data_raw, 
              target_raw, 
              l1_strength=0.5,
              active_features_threshold=0.1
             )
# Out:
# L2 tracking error: 0.03

# %% [markdown]
# ### Lasso path

# %%
path, active_features_path, grid = model.lasso_path(n_l1_strength=20,
                                                    l1_min=0.001,
                                                    l1_max=1.0,
                                                    plot_path=True,
                                                    plot_active_features_path=True,
                                                    add_legend=False,
                                                   )
